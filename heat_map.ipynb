# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore") #过滤掉警告的意思
from pyforest import *

# %%
data3 = pd.read_excel("C题数据.xlsx", "data3")
datalist = data3.groupby(data3.index//3).mean()
data = datalist.corr()
data = data.iloc[:5, :5]

ax = plt.subplots(figsize=(10, 8), dpi=200)
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

ax = sns.heatmap(data, vmax=1, vmin=-1, square=True, annot=True)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0, 0.5, '接收距离'),
#   Text(0, 1.5, '热风速度'),
#   Text(0, 2.5, '厚度'),
#   Text(0, 3.5, '孔隙率'),
#   Text(0, 4.5, '压缩回弹性率')])

# %%
data3 = pd.read_excel("C题数据.xlsx", "data3")
datalist = data3
print(datalist.corr())

ax = plt.subplots(figsize=(5, 4), dpi=200)
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

ax = sns.heatmap(datalist.corr().iloc[2:5, 2:5], vmax=1, vmin=-1, square=True, annot=True)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# Out:
#                  接收距离(cm)   热风速度(r/min)      厚度mm    孔隙率（%）  压缩回弹性率（%）  \
# 接收距离(cm)     1.000000e+00  6.396779e-16  0.816890  0.730050  -0.402620
# 热风速度(r/min)  6.396779e-16  1.000000e+00  0.555201  0.521922  -0.320321
# 厚度mm         8.168898e-01  5.552010e-01  1.000000  0.896965  -0.527047
# 孔隙率（%）       7.300497e-01  5.219222e-01  0.896965  1.000000  -0.323640
# 压缩回弹性率（%）   -4.026198e-01 -3.203214e-01 -0.527047 -0.323640   1.000000
# 过滤阻力Pa      -6.110671e-01 -4.724723e-01 -0.795244 -0.736532   0.497562
# 过滤效率（%）     -6.774692e-01  9.011290e-02 -0.482529 -0.400708  -0.010066
# 透气性 mm/s     6.362700e-01 -3.014081e-01  0.353674  0.278720  -0.165227
#
#                过滤阻力Pa   过滤效率（%）  透气性 mm/s
# 接收距离(cm)    -0.611067 -0.677469  0.636270
# 热风速度(r/min) -0.472472  0.090113 -0.301408
# 厚度mm        -0.795244 -0.482529  0.353674
# 孔隙率（%）      -0.736532 -0.400708  0.278720
# 压缩回弹性率（%）    0.497562 -0.010066 -0.165227
# 过滤阻力Pa       1.000000  0.374042 -0.410408
# ...

# %%
data3 = pd.read_excel("C题数据.xlsx", "data3")
datalist = data3
print(datalist.corr())

ax = plt.subplots(figsize=(5, 4), dpi=200)
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

ax = sns.heatmap(datalist.corr().iloc[5:8, 5:8], vmax=1, vmin=-1, square=True, annot=True)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# Out:
#                  接收距离(cm)   热风速度(r/min)      厚度mm    孔隙率（%）  压缩回弹性率（%）  \
# 接收距离(cm)     1.000000e+00  6.396779e-16  0.816890  0.730050  -0.402620
# 热风速度(r/min)  6.396779e-16  1.000000e+00  0.555201  0.521922  -0.320321
# 厚度mm         8.168898e-01  5.552010e-01  1.000000  0.896965  -0.527047
# 孔隙率（%）       7.300497e-01  5.219222e-01  0.896965  1.000000  -0.323640
# 压缩回弹性率（%）   -4.026198e-01 -3.203214e-01 -0.527047 -0.323640   1.000000
# 过滤阻力Pa      -6.110671e-01 -4.724723e-01 -0.795244 -0.736532   0.497562
# 过滤效率（%）     -6.774692e-01  9.011290e-02 -0.482529 -0.400708  -0.010066
# 透气性 mm/s     6.362700e-01 -3.014081e-01  0.353674  0.278720  -0.165227
#
#                过滤阻力Pa   过滤效率（%）  透气性 mm/s
# 接收距离(cm)    -0.611067 -0.677469  0.636270
# 热风速度(r/min) -0.472472  0.090113 -0.301408
# 厚度mm        -0.795244 -0.482529  0.353674
# 孔隙率（%）      -0.736532 -0.400708  0.278720
# 压缩回弹性率（%）    0.497562 -0.010066 -0.165227
# 过滤阻力Pa       1.000000  0.374042 -0.410408
# ...
